# %% [markdown]
# <a href="https://colab.research.google.com/github/Raghul1694/introduction1/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from tabulate import tabulate
import traceback
import numpy as np
import matplotlib.pyplot as plt
from requests import get
import requests
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import pandas as pd
df = pd.read_csv("/content/gdrive/MyDrive/openpowerlifting-2021-12-10-b420db66.csv")
df
# Out:
# <ipython-input-6-60a4de7edea3>:2: DtypeWarning: Columns (33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/gdrive/MyDrive/openpowerlifting-2021-12-10-b420db66.csv")
#                            Name Sex Event   Equipment   Age AgeClass  \
# 0                   Alona Vladi   F   SBD         Raw  33.0    24-34
# 1            Galina Solovyanova   F   SBD         Raw  43.0    40-44
# 2                Daniil Voronin   M   SBD         Raw  15.5    16-17
# 3                Aleksey Krasov   M   SBD         Raw  35.0    35-39
# 4        Margarita Pleschenkova   M   SBD         Raw  26.5    24-34
# ...                         ...  ..   ...         ...   ...      ...
# 2569941            Inna Orobets   F   SBD  Single-ply  45.0    45-49
# 2569942             Ágnes Szabó   F   SBD  Single-ply  27.5    24-34
# 2569943   Brenda van der Meulen   F   SBD  Single-ply  37.5    35-39
# 2569944            Kelly Phasey   F   SBD  Single-ply  39.5    35-39
# 2569945  Hildeborg Juvet Hugdal   F   SBD  Single-ply  32.5    24-34
#
#         BirthYearClass Division  BodyweightKg WeightClassKg  ...  Tested  \
# 0                24-39        O         58.30            60  ...     Yes
# 1                40-49       M1         73.10            75  ...     Yes
# 2                14-18        T         67.40            75  ...     Yes
# 3                24-39        O         66.65            75  ...     Yes
# 4                24-39        O         72.45            75  ...     Yes
# ...                ...      ...           ...           ...  ...     ...
# 2569941          40-49     Open        109.30           84+  ...     Yes
# 2569942          24-39     Open        113.22           84+  ...     Yes
# 2569943          24-39     Open        110.79           84+  ...     Yes
# 2569944          40-49     Open        124.53           84+  ...     Yes
# 2569945          24-39     Open        123.00           84+  ...     Yes
#
#              Country  State  Federation  ParentFederation        Date  \
# 0             Russia    NaN         GFP               NaN  2019-05-11
# 1             Russia    NaN         GFP               NaN  2019-05-11
# 2             Russia    NaN         GFP               NaN  2019-05-11
# 3             Russia    NaN         GFP               NaN  2019-05-11
# 4             Russia    NaN         GFP               NaN  2019-05-11
# ...              ...    ...         ...               ...         ...
# 2569941      Ukraine    NaN         IPF               IPF  2016-11-14
# 2569942      Hungary    NaN         IPF               IPF  2016-11-14
# 2569943  Netherlands    NaN         IPF               IPF  2016-11-14
# 2569944      England    NaN         IPF               IPF  2016-11-14
# 2569945       Norway    NaN         IPF               IPF  2016-11-14
#
#          MeetCountry  MeetState  MeetTown                  MeetName
# 0             Russia        NaN   Bryansk           Open Tournament
# 1             Russia        NaN   Bryansk           Open Tournament
# 2             Russia        NaN   Bryansk           Open Tournament
# 3             Russia        NaN   Bryansk           Open Tournament
# 4             Russia        NaN   Bryansk           Open Tournament
# ...              ...        ...       ...                       ...
# 2569941          USA        NaN   Orlando  World Open Championships
# 2569942          USA        NaN   Orlando  World Open Championships
# 2569943          USA        NaN   Orlando  World Open Championships
# 2569944          USA        NaN   Orlando  World Open Championships
# 2569945          USA        NaN   Orlando  World Open Championships
#
# [2569946 rows x 41 columns]

# %%
import pandas as pd
from tabulate import tabulate
df_state_men = df.loc[df["Sex"]=="M"].groupby(["State"]).size().to_frame("count").reset_index()
df1 = df_state_men.sort_values(by="count",ascending=False)
print("Top 10 states for Men")
print(tabulate(df1.head(10), headers='keys', tablefmt='psql'))
# Out:
# Top 10 states for Men
# +-----+---------+---------+
# |     | State   |   count |
# |-----+---------+---------|
# |  13 | CA      |   32456 |
# | 114 | TX      |   23517 |
# |  81 | OH      |   11486 |
# |  28 | FL      |   11341 |
# |  85 | PA      |   10857 |
# |  63 | NC      |   10510 |
# |  80 | NY      |    9523 |
# | 116 | VA      |    9312 |
# |  83 | ON      |    9052 |
# |   7 | AZ      |    7632 |
# +-----+---------+---------+

# %%
df_state_women_2021 = df_2021.loc[df2["Sex"]=="F"].groupby(["State"]).size().to_frame("count").reset_index()
df2 = df_state_women_2021.sort_values(by="count",ascending=False)
print("Top 10 states for Women in 2021")
print(tabulate(df2_2021.head(10), headers='keys', tablefmt='psql'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-6dc45fffa878> in <cell line: 1>()
# ----> 1 df_state_women_2021 = df_2021.loc[df2["Sex"]=="F"].groupby(["State"]).size().to_frame("count").reset_index()
#       2 df2 = df_state_women_2021.sort_values(by="count",ascending=False)
#       3 print("Top 10 states for Women in 2021")
#       4 print(tabulate(df2_2021.head(10), headers='keys', tablefmt='psql'))
#
# NameError: name 'df_2021' is not defined

# %%
import pandas as pd
from tabulate import tabulate
df_state_men = df.loc[df["Sex"]=="M"].groupby(["State"]).size().to_frame("count").reset_index()
df1 = df_state_men.sort_values(by="count",ascending=False)
print("Top 10 states for Men")
print(tabulate(df1.head(10), headers='keys', tablefmt='psql'))
# Out:
# Top 10 states for Men
# +-----+---------+---------+
# |     | State   |   count |
# |-----+---------+---------|
# |  13 | CA      |   32456 |
# | 114 | TX      |   23517 |
# |  81 | OH      |   11486 |
# |  28 | FL      |   11341 |
# |  85 | PA      |   10857 |
# |  63 | NC      |   10510 |
# |  80 | NY      |    9523 |
# | 116 | VA      |    9312 |
# |  83 | ON      |    9052 |
# |   7 | AZ      |    7632 |
# +-----+---------+---------+

# %%
import matplotlib.pyplot as plt

data = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
        "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0) #here the starting angle is the origin "0"

plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt

data = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
        "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0) #here the starting angle is the origin "0"

plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt

data = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
        "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0) #here the starting angle is the origin "0"

plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt

data = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
        "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0) #here the starting angle is the origin "0"

plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt

data = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
        "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0) #here the starting angle is the origin "0"

plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt

data = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
        "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0) #here the starting angle is the origin "0"

plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt

data = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
        "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0) #here the starting angle is the origin "0"

plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt

data = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
        "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0) #here the starting angle is the origin "0"

plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt

data = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
        "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0) #here the starting angle is the origin "0"

plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt

data = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
        "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0) #here the starting angle is the origin "0"

plt.axis("equal")
plt.show()
