# %% [markdown]
# <a href="https://colab.research.google.com/github/Raghul1694/introduction1/blob/main/project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/Copy of us.csv')
df_2 = pd.read_csv('/content/drive/MyDrive/Copy of us-states.csv')
df_3 = pd.read_csv('/content/drive/MyDrive/Copy of us-counties.csv')
df_4 = pd.read_csv('/content/drive/MyDrive/Copy of us-counties-recent.csv')

# %%
df_2.head(5)
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
df_3.tail(5)
# Out:
#                date      county    state     fips  cases  deaths
# 2099369  2022-01-09  Sweetwater  Wyoming  56037.0   8506   110.0
# 2099370  2022-01-09       Teton  Wyoming  56039.0   7025    14.0
# 2099371  2022-01-09       Uinta  Wyoming  56041.0   4264    34.0
# 2099372  2022-01-09    Washakie  Wyoming  56043.0   1914    39.0
# 2099373  2022-01-09      Weston  Wyoming  56045.0   1263    16.0

# %%
import pandas as pd # imports the pandas library and assigns it to the alias 'pd'

# Defines the variable df_us_states by reading the csv file
df_2 = pd.read_csv('/content/drive/MyDrive/Copy of us-states.csv')
# Defines the variable df_us_countries by reading the csv file
df_3 = pd.read_csv('/content/drive/MyDrive/Copy of us-counties.csv')

df_new = pd.merge(df_us_states,df_us_countries, how="outer")
df_new.head(5)
# Out:
#          date       state  fips  cases  deaths county
# 0  2020-01-21  Washington  53.0      1     0.0    NaN
# 1  2020-01-22  Washington  53.0      1     0.0    NaN
# 2  2020-01-23  Washington  53.0      1     0.0    NaN
# 3  2020-01-24    Illinois  17.0      1     0.0    NaN
# 4  2020-01-24  Washington  53.0      1     0.0    NaN

# %%
df_new = pd.merge(df_1,df_2, how="outer")
df_new.head(5)
# Out:
#          date  cases  deaths       state  fips
# 0  2020-01-21      1       0  Washington  53.0
# 1  2020-01-22      1       0  Washington  53.0
# 2  2020-01-23      1       0  Washington  53.0
# 3  2020-01-24      2       0         NaN   NaN
# 4  2020-01-25      3       0         NaN   NaN

# %%
#Top 10 states having highest total death in year 2020
from datetime import datetime # imports the datetime object from the datetime module.

def getyear(row):
  return datetime.strptime(row["date"], "%Y-%m-%d").year

df_new["year"] = df_new.apply(getyear, axis=1)
df_in2020 = df_new.where(df_new["year"] == 2020)
df_top10 = df_in2020.groupby(["state"])["deaths"].sum().to_frame("count").reset_index()
df_top10_2020 = df_top10.sort_values(by="count", ascending=False)
df_top10_2020.head(10)
# Out:
#             state      count
# 33       New York  8320598.0
# 31     New Jersey  3817150.0
# 4      California  3065113.0
# 46          Texas  2927740.0
# 9         Florida  2632238.0
# 22  Massachusetts  2222455.0
# 14       Illinois  2211390.0
# 40   Pennsylvania  2002641.0
# 23       Michigan  1837617.0
# 10        Georgia  1363977.0

# %%
#Top 10 states having highest total death in the year 2021
df_new["year"] = df_new.apply(getyear, axis=1)
df_in2021 = df_new.where(df_new["year"] == 2021)
df_top10 = df_in2021.groupby(["state"])["deaths"].sum().to_frame("count").reset_index()
df_top10_2021 = df_top10.sort_values(by="count", ascending=False)
df_top10_2021.head(10)
# Out:
#            state       count
# 5     California  22532428.0
# 47         Texas  20088817.0
# 34      New York  18918470.0
# 10       Florida  15333245.0
# 41  Pennsylvania  10025434.0
# 32    New Jersey   9406432.0
# 15      Illinois   9306526.0
# 11       Georgia   7791745.0
# 24      Michigan   7460163.0
# 38          Ohio   7327426.0

# %%
#Top 10 states having highest avg death in the year 2020
df_new["year"] = df_new.apply(getyear, axis=1)
df_in2020 = df_new.where(df_new["year"] == 2020)
df_top10 = df_in2020.groupby(["state"])["deaths"].mean().to_frame("count").reset_index()
df_top10_2020 = df_top10.sort_values(by="count", ascending=False)
df_top10_2020.head(10)
# Out:
#             state         count
# 33       New York  27191.496732
# 31     New Jersey  12597.854785
# 46          Texas   9036.234568
# 4      California   8962.318713
# 9         Florida   8602.084967
# 40   Pennsylvania   6653.292359
# 22  Massachusetts   6634.194030
# 14       Illinois   6447.201166
# 23       Michigan   6187.262626
# 10        Georgia   4472.055738

# %%
#Top 10 states having highest avg death in the year 2021
df_new["year"] = df_new.apply(getyear, axis=1)
df_in2021 = df_new.where(df_new["year"] == 2021)
df_top10 = df_in2021.groupby(["state"])["deaths"].mean().to_frame("count").reset_index()
df_top10_2021 = df_top10.sort_values(by="count", ascending=False)
df_top10_2021.head(10)
# Out:
#            state         count
# 5     California  61732.679452
# 47         Texas  55037.854795
# 34      New York  51831.424658
# 10       Florida  42008.890411
# 41  Pennsylvania  27466.942466
# 32    New Jersey  25771.046575
# 15      Illinois  25497.331507
# 11       Georgia  21347.246575
# 24      Michigan  20438.802740
# 38          Ohio  20075.139726

# %%
#Top 10 states having highest avg death in the year 2021
df_new["year"] = df_new.apply(getyear, axis=1)
df_in2021 = df_new.where(df_new["year"] == 2021)
df_top10 = df_in2021.groupby(["state"])["deaths"].mean().to_frame("count").reset_index()
df_top10_2021 = df_top10.sort_values(by="count", ascending=False)
df_top10_2021.head(10)
# Out:
#            state         count
# 5     California  61732.679452
# 47         Texas  55037.854795
# 34      New York  51831.424658
# 10       Florida  42008.890411
# 41  Pennsylvania  27466.942466
# 32    New Jersey  25771.046575
# 15      Illinois  25497.331507
# 11       Georgia  21347.246575
# 24      Michigan  20438.802740
# 38          Ohio  20075.139726
